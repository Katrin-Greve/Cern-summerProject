# %%
import preparing_data as prep
# Out:
# Welcome to JupyROOT 6.30/04

# %%
prompt= prep.get_prompt()
nonprompt=prep.get_nonprompt()
bckg=prep.get_bckg()
vars=prep.var_draw_all()
# Out:
# [1.109645873305327, 1.1217140269810215]

# %%
prep.plot_dist(prep.get_rawdata(),"fMass",leg_labels="raw data", fs=(8,3),alpha=0.5)
prep.plot_gauss(fs=(8,3))
prep.plot_dist(bckg,"fMass",leg_labels="bckg",fs=(8,3),alpha=0.5)

# %%
prep.plot_dist(prep.get_rawMC(),"fMass",leg_labels="raw MC", fs=(8,3),alpha=0.5)
prep.plot_dist(prompt,"fMass",leg_labels="prompt", fs=(8,3),alpha=0.5)
prep.plot_dist(nonprompt,"fMass",leg_labels="non prompt", fs=(8,3),alpha=0.5)

# %%
prep.plot_dist([prompt,nonprompt,bckg],vars, fs=(15,10),leg_labels=["prompt","non-prompt", "bckg"])

# %%
prep.plot_correl([prompt,nonprompt,bckg, prep.get_rawdata()],vars,['prompt','nonprompt','bckg','raw data'])
